# %%
import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
from api_key import key
# key

# %%
quandl.ApiConfig.api_key = key

# %%
data = quandl.get_table('WIKI/PRICES', ticker = ['AAPL', 'MSFT', 'WMT'], 
#                         qopts = { 'columns': [
#                             'ticker', 
#                             'date', 
#                             'adj_close',
#                             'open',
#                             'close'
#                         ] 
#                                 }, 
                        date = { 'gte': '2015-12-31', 'lte': '2016-12-31' }, 
                        paginate=True)
data.head()
# Out:
#      ticker       date   open    high    low  close     volume  ex-dividend  \
# None
# 0       WMT 2016-12-30  69.12  69.430  68.83  69.12  6889478.0          0.0
# 1       WMT 2016-12-29  69.21  69.520  69.12  69.26  4298446.0          0.0
# 2       WMT 2016-12-28  69.94  70.000  69.26  69.31  4875301.0          0.0
# 3       WMT 2016-12-27  69.30  69.815  69.25  69.70  4435668.0          0.0
# 4       WMT 2016-12-23  69.43  69.749  69.36  69.54  4803947.0          0.0
#
#       split_ratio   adj_open   adj_high    adj_low  adj_close  adj_volume
# None
# 0             1.0  67.742045  68.045865  67.457826  67.742045   6889478.0
# 1             1.0  67.830251  68.134071  67.742045  67.879254   4298446.0
# 2             1.0  68.545698  68.604502  67.879254  67.928257   4875301.0
# 3             1.0  67.918457  68.423190  67.869453  68.310482   4435668.0
# 4             1.0  68.045865  68.358505  67.977260  68.153672   4803947.0

# %%
data.ticker.unique()
# Out:
# array(['WMT', 'MSFT', 'AAPL'], dtype=object)

# %%
for i in data.ticker.unique():
    data_1 = data.loc[data.ticker == f'{i}']
    plt.plot(data_1.date, data_1.adj_close, label=f'{i}')
    plt.legend()
    plt.xlabel('Date')
    plt.ylabel('')
    plt.title('')
    plt.plot()

# %%
wmnt_data = data.loc[data.ticker == 'WMT']
plt.plot(wmnt_data.date, wmnt_data.adj_close)
plt.show()

# %%
MSFT_data = data.loc[data.ticker == 'MSFT']

# %%
MSFT_data
# Out:
#      ticker       date   open     high    low  close      volume  ex-dividend  \
# None
# 253    MSFT 2016-12-30  62.96  62.9900  62.03  62.14  25579908.0          0.0
# 254    MSFT 2016-12-29  62.86  63.2000  62.73  62.90  10250582.0          0.0
# 255    MSFT 2016-12-28  63.40  63.4000  62.83  62.99  14653348.0          0.0
# 256    MSFT 2016-12-27  63.21  64.0700  63.21  63.28  11763173.0          0.0
# 257    MSFT 2016-12-23  63.45  63.5400  62.80  63.24  12403819.0          0.0
# ...     ...        ...    ...      ...    ...    ...         ...          ...
# 501    MSFT 2016-01-07  52.70  53.4850  52.07  52.17  56564852.0          0.0
# 502    MSFT 2016-01-06  54.32  54.4001  53.64  54.05  39518863.0          0.0
# 503    MSFT 2016-01-05  54.93  55.3900  54.54  55.05  34079674.0          0.0
# 504    MSFT 2016-01-04  54.32  54.8000  53.39  54.80  53777963.0          0.0
# 505    MSFT 2015-12-31  56.04  56.1900  55.42  55.48  27334061.0          0.0
#
# ...

# %%
MSFT_data_copy = MSFT_data.copy()
MSFT_data_copy
# Out:
#      ticker       date   open     high    low  close      volume  ex-dividend  \
# None
# 253    MSFT 2016-12-30  62.96  62.9900  62.03  62.14  25579908.0          0.0
# 254    MSFT 2016-12-29  62.86  63.2000  62.73  62.90  10250582.0          0.0
# 255    MSFT 2016-12-28  63.40  63.4000  62.83  62.99  14653348.0          0.0
# 256    MSFT 2016-12-27  63.21  64.0700  63.21  63.28  11763173.0          0.0
# 257    MSFT 2016-12-23  63.45  63.5400  62.80  63.24  12403819.0          0.0
# ...     ...        ...    ...      ...    ...    ...         ...          ...
# 501    MSFT 2016-01-07  52.70  53.4850  52.07  52.17  56564852.0          0.0
# 502    MSFT 2016-01-06  54.32  54.4001  53.64  54.05  39518863.0          0.0
# 503    MSFT 2016-01-05  54.93  55.3900  54.54  55.05  34079674.0          0.0
# 504    MSFT 2016-01-04  54.32  54.8000  53.39  54.80  53777963.0          0.0
# 505    MSFT 2015-12-31  56.04  56.1900  55.42  55.48  27334061.0          0.0
#
# ...

# %%
X = MSFT_data_copy.drop(['ticker', 'close'], axis=1)
# X

# %%
y = MSFT_data_copy['close'].values.reshape(-1,1)
# y

# %%
import sklearn.metrics as metrics
def regression_results(y_true, y_pred):
# Regression metrics
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    mean_squared_log_error=metrics.mean_squared_log_error(y_true, y_pred)
    median_absolute_error=metrics.median_absolute_error(y_true, y_pred)
    r2=metrics.r2_score(y_true, y_pred)
    print('explained_variance: ', round(explained_variance,4))    
    print('mean_squared_log_error: ', round(mean_squared_log_error,4))
    print('r2: ', round(r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))
